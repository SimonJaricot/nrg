# %% [markdown]
# # Cleaning data
#
# After a long wait to download the data files, it's high time to start exploring the data!

# %%
import pandas as pd

# read the json file
file_path = '../data/conso.json'
df = pd.read_json(file_path)
# it's long...

# %%
df.head()

# %%
# save to pickle
df.to_pickle('../data/conso.pkl')

# %%
# read it back, muck faster than json
# and keep will keep types
df = pd.read_pickle('../data/conso.pkl')

# %%
# Sooooo, what's in there?
df.shape
# Out:
# (2121408, 32)

# %%
# First step is to drop columns with all NaN
# This is how we do it
df.dropna(axis=1, how='all', inplace=True)

# %%
df.shape  # One down !
# Out:
# (2121408, 31)

# %%
# Let's use the auto cast feature of pandas, sometimes it's working neat
df = df.convert_dtypes()

# %%
# And sometimes, it's not
df.dtypes
# Out:
# code_insee_region               Int64
# libelle_region         string[python]
# nature                 string[python]
# date                   datetime64[ns]
# heure                  string[python]
# date_heure             string[python]
# consommation                    Int64
# thermique                       Int64
# nucleaire                       Int64
# eolien                 string[python]
# solaire                         Int64
# hydraulique                     Int64
# pompage                         Int64
# bioenergies                     Int64
# ech_physiques                   Int64
# stockage_batterie               Int64
# destockage_batterie             Int64
# eolien_terrestre                Int64
# eolien_offshore                 Int64
# tco_thermique                 Float64
# tch_thermique                 Float64
# tco_nucleaire                 Float64
# tch_nucleaire                 Float64
# tco_eolien                    Float64
# tch_eolien                    Float64
# tco_solaire                   Float64
# tch_solaire                   Float64
# tco_hydraulique               Float64
# tch_hydraulique               Float64
# tco_bioenergies               Float64
# tch_bioenergies               Float64
# dtype: object

# %%
# Here's the reason why the colum eolien is not a number
# Pandas won't cast it to a number because of the 'ND' string
# We will replace it with NaN, not by using .astype() or .replace()
# but by forcing the cast with pd.to_numeric(errors='coerce')
# This will replace any non number with NaN
df['eolien'].head(20)
# Out:
# 0       ND
# 1       ND
# 2       ND
# 3       ND
# 4       ND
# 5       ND
# 6       ND
# 7       ND
# 8       ND
# 9       ND
# 10      ND
# 11      ND
# 12    1109
# 13     508
# 14      16
# 15     182
# 16     106
# 17     367
# 18     216
# 19      12
# Name: eolien, dtype: string

# %%
# force cast to int for eolien column
df['eolien'] = pd.to_numeric(df['eolien'], errors='coerce').astype('Int64')

# %%
df['eolien'].head(20)
# Out:
# 0     <NA>
# 1     <NA>
# 2     <NA>
# 3     <NA>
# 4     <NA>
# 5     <NA>
# 6     <NA>
# 7     <NA>
# 8     <NA>
# 9     <NA>
# 10    <NA>
# 11    <NA>
# 12    1109
# 13     508
# 14      16
# 15     182
# 16     106
# 17     367
# 18     216
# 19      12
# Name: eolien, dtype: Int64

# %%
# I think this is the same for the date_heure column
# Since it's a UTC date, pandas seems to say "do it yourself, I don't want to break anything"
# Let's do it ourselves !
# First, let's check the data
df['date_heure'].head()  # UTC +1
# Out:
# 0    2013-01-01T00:00:00+01:00
# 1    2013-01-01T00:00:00+01:00
# 2    2013-01-01T00:00:00+01:00
# 3    2013-01-01T00:00:00+01:00
# 4    2013-01-01T00:00:00+01:00
# Name: date_heure, dtype: string

# %%
# Let's convert it to UTC
pd.to_datetime(df['date_heure'].head(), utc=True)
# Uh uh... the date is converted to UTC
# So 1 hour is removed from the date
# And the data won't start at midnight anymore !
# Out:
# 0   2012-12-31 23:00:00+00:00
# 1   2012-12-31 23:00:00+00:00
# 2   2012-12-31 23:00:00+00:00
# 3   2012-12-31 23:00:00+00:00
# 4   2012-12-31 23:00:00+00:00
# Name: date_heure, dtype: datetime64[ns, UTC]

# %%
# What's that ?
df.loc[df['date_heure'].str.contains('+02', regex=False), 'date_heure']  # Summer time !
# Out:
# 51312      2013-03-31T03:00:00+02:00
# 51313      2013-03-31T03:00:00+02:00
# 51314      2013-03-31T03:00:00+02:00
# 51315      2013-03-31T03:00:00+02:00
# 51316      2013-03-31T03:00:00+02:00
#                      ...
# 2067307    2022-10-30T01:30:00+02:00
# 2067308    2022-10-30T01:30:00+02:00
# 2067309    2022-10-30T01:30:00+02:00
# 2067310    2022-10-30T01:30:00+02:00
# 2067311    2022-10-30T01:30:00+02:00
# Name: date_heure, Length: 1229760, dtype: string

# %%
# We'll convert the date_heure column to UTC, then set the timezone to 'Europe/Paris' and we're done !
new_date = pd.to_datetime(df['date_heure'], utc=True).dt.tz_convert('Europe/Paris')  # this is how we do it
new_date.head()
# Out:
# 0   2013-01-01 00:00:00+01:00
# 1   2013-01-01 00:00:00+01:00
# 2   2013-01-01 00:00:00+01:00
# 3   2013-01-01 00:00:00+01:00
# 4   2013-01-01 00:00:00+01:00
# Name: date_heure, dtype: datetime64[ns, Europe/Paris]

# %%
# We're good !
df['date_heure'] = new_date

# %%
df.dtypes  # Nice !
# Out:
# code_insee_region                             Int64
# libelle_region                       string[python]
# nature                               string[python]
# date                                 datetime64[ns]
# heure                                string[python]
# date_heure             datetime64[ns, Europe/Paris]
# consommation                                  Int64
# thermique                                     Int64
# nucleaire                                     Int64
# eolien                                        Int64
# solaire                                       Int64
# hydraulique                                   Int64
# pompage                                       Int64
# bioenergies                                   Int64
# ech_physiques                                 Int64
# stockage_batterie                             Int64
# destockage_batterie                           Int64
# eolien_terrestre                              Int64
# eolien_offshore                               Int64
# tco_thermique                               Float64
# tch_thermique                               Float64
# tco_nucleaire                               Float64
# tch_nucleaire                               Float64
# tco_eolien                                  Float64
# tch_eolien                                  Float64
# tco_solaire                                 Float64
# tch_solaire                                 Float64
# tco_hydraulique                             Float64
# tch_hydraulique                             Float64
# tco_bioenergies                             Float64
# tch_bioenergies                             Float64
# dtype: object

# %%
# Let's check the data
df.head(20)
# Out:
#     code_insee_region              libelle_region               nature  \
# 0                  84        Auvergne-Rhône-Alpes  Données définitives
# 1                  44                   Grand Est  Données définitives
# 2                  27     Bourgogne-Franche-Comté  Données définitives
# 3                  76                   Occitanie  Données définitives
# 4                  28                   Normandie  Données définitives
# 5                  93  Provence-Alpes-Côte d'Azur  Données définitives
# 6                  53                    Bretagne  Données définitives
# 7                  11               Île-de-France  Données définitives
# 8                  24         Centre-Val de Loire  Données définitives
# 9                  32             Hauts-de-France  Données définitives
# 10                 75          Nouvelle-Aquitaine  Données définitives
# 11                 52            Pays de la Loire  Données définitives
# 12                 44                   Grand Est  Données définitives
# 13                 24         Centre-Val de Loire  Données définitives
# 14                 11               Île-de-France  Données définitives
# 15                 52            Pays de la Loire  Données définitives
# 16                 27     Bourgogne-Franche-Comté  Données définitives
# 17                 76                   Occitanie  Données définitives
# 18                 28                   Normandie  Données définitives
# 19                 93  Provence-Alpes-Côte d'Azur  Données définitives
#
#          date  heure                date_heure  consommation  thermique  \
# 0  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 1  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 2  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 3  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 4  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 5  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 6  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 7  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 8  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 9  2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 10 2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 11 2013-01-01  00:00 2013-01-01 00:00:00+01:00          <NA>       <NA>
# 12 2013-01-01  00:30 2013-01-01 00:30:00+01:00          4943        319
# 13 2013-01-01  00:30 2013-01-01 00:30:00+01:00          2476         90
# 14 2013-01-01  00:30 2013-01-01 00:30:00+01:00          9134        685
# 15 2013-01-01  00:30 2013-01-01 00:30:00+01:00          3595        127
# 16 2013-01-01  00:30 2013-01-01 00:30:00+01:00          2357        236
# 17 2013-01-01  00:30 2013-01-01 00:30:00+01:00          5228         78
# 18 2013-01-01  00:30 2013-01-01 00:30:00+01:00          3683        432
# 19 2013-01-01  00:30 2013-01-01 00:30:00+01:00          5570        537
#
#     nucleaire  eolien  ...  tco_nucleaire  tch_nucleaire  tco_eolien  \
# 0        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 1        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 2        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 3        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 4        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 5        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 6        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 7        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 8        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 9        <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 10       <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 11       <NA>    <NA>  ...           <NA>           <NA>        <NA>
# 12       9137    1109  ...           <NA>           <NA>        <NA>
# 13       9085     508  ...           <NA>           <NA>        <NA>
# 14       <NA>      16  ...           <NA>           <NA>        <NA>
# 15       <NA>     182  ...           <NA>           <NA>        <NA>
# 16       <NA>     106  ...           <NA>           <NA>        <NA>
# 17       2497     367  ...           <NA>           <NA>        <NA>
# 18       8200     216  ...           <NA>           <NA>        <NA>
# 19       <NA>      12  ...           <NA>           <NA>        <NA>
#
#     tch_eolien  tco_solaire  tch_solaire  tco_hydraulique  tch_hydraulique  \
# 0         <NA>         <NA>         <NA>             <NA>             <NA>
# 1         <NA>         <NA>         <NA>             <NA>             <NA>
# 2         <NA>         <NA>         <NA>             <NA>             <NA>
# 3         <NA>         <NA>         <NA>             <NA>             <NA>
# 4         <NA>         <NA>         <NA>             <NA>             <NA>
# 5         <NA>         <NA>         <NA>             <NA>             <NA>
# 6         <NA>         <NA>         <NA>             <NA>             <NA>
# 7         <NA>         <NA>         <NA>             <NA>             <NA>
# 8         <NA>         <NA>         <NA>             <NA>             <NA>
# 9         <NA>         <NA>         <NA>             <NA>             <NA>
# 10        <NA>         <NA>         <NA>             <NA>             <NA>
# 11        <NA>         <NA>         <NA>             <NA>             <NA>
# 12        <NA>         <NA>         <NA>             <NA>             <NA>
# 13        <NA>         <NA>         <NA>             <NA>             <NA>
# 14        <NA>         <NA>         <NA>             <NA>             <NA>
# 15        <NA>         <NA>         <NA>             <NA>             <NA>
# 16        <NA>         <NA>         <NA>             <NA>             <NA>
# 17        <NA>         <NA>         <NA>             <NA>             <NA>
# 18        <NA>         <NA>         <NA>             <NA>             <NA>
# 19        <NA>         <NA>         <NA>             <NA>             <NA>
#
#     tco_bioenergies  tch_bioenergies
# 0              <NA>             <NA>
# 1              <NA>             <NA>
# 2              <NA>             <NA>
# 3              <NA>             <NA>
# 4              <NA>             <NA>
# 5              <NA>             <NA>
# 6              <NA>             <NA>
# 7              <NA>             <NA>
# 8              <NA>             <NA>
# 9              <NA>             <NA>
# 10             <NA>             <NA>
# 11             <NA>             <NA>
# 12             <NA>             <NA>
# 13             <NA>             <NA>
# 14             <NA>             <NA>
# 15             <NA>             <NA>
# 16             <NA>             <NA>
# 17             <NA>             <NA>
# 18             <NA>             <NA>
# 19             <NA>             <NA>
#
# [20 rows x 31 columns]

# %%
# It's seems we have some NaN in the consommation column
# We will drop the records with NaN in ths column, 
df['consommation'].isna().sum()
# Out:
# np.int64(12)

# %%
# drop rows where the column 'consommation' is NaN
df.dropna(subset=['consommation'], inplace=True)

# %%
df.head()
# Out:
#     code_insee_region           libelle_region               nature  \
# 12                 44                Grand Est  Données définitives
# 13                 24      Centre-Val de Loire  Données définitives
# 14                 11            Île-de-France  Données définitives
# 15                 52         Pays de la Loire  Données définitives
# 16                 27  Bourgogne-Franche-Comté  Données définitives
#
#          date  heure                date_heure  consommation  thermique  \
# 12 2013-01-01  00:30 2013-01-01 00:30:00+01:00          4943        319
# 13 2013-01-01  00:30 2013-01-01 00:30:00+01:00          2476         90
# 14 2013-01-01  00:30 2013-01-01 00:30:00+01:00          9134        685
# 15 2013-01-01  00:30 2013-01-01 00:30:00+01:00          3595        127
# 16 2013-01-01  00:30 2013-01-01 00:30:00+01:00          2357        236
#
#     nucleaire  eolien  ...  tco_nucleaire  tch_nucleaire  tco_eolien  \
# 12       9137    1109  ...           <NA>           <NA>        <NA>
# 13       9085     508  ...           <NA>           <NA>        <NA>
# 14       <NA>      16  ...           <NA>           <NA>        <NA>
# 15       <NA>     182  ...           <NA>           <NA>        <NA>
# 16       <NA>     106  ...           <NA>           <NA>        <NA>
#
#     tch_eolien  tco_solaire  tch_solaire  tco_hydraulique  tch_hydraulique  \
# 12        <NA>         <NA>         <NA>             <NA>             <NA>
# 13        <NA>         <NA>         <NA>             <NA>             <NA>
# 14        <NA>         <NA>         <NA>             <NA>             <NA>
# 15        <NA>         <NA>         <NA>             <NA>             <NA>
# 16        <NA>         <NA>         <NA>             <NA>             <NA>
#
#     tco_bioenergies  tch_bioenergies
# 12             <NA>             <NA>
# 13             <NA>             <NA>
# 14             <NA>             <NA>
# 15             <NA>             <NA>
# 16             <NA>             <NA>
#
# [5 rows x 31 columns]

# %%
# consommatin is in MW, same for production

# %%
# sort the dataframes by date_heure ascending
df.sort_values('date_heure', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.set_index('date_heure', inplace=True)

df.to_pickle('../data/conso-processed.pkl')
